# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv("used_cars_data.csv")

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df.shape
# Out:
# (7253, 14)

# %%
df.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %%
df.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %%
df = df.drop(["S.No."], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %%
from datetime import date
date.today().year
df["Car_Age"] = date.today().year - df["Year"]
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age
# 0        NaN   1.75       15
# ...

# %%
df["Brand"] = df.Name.str.split().str.get(0)

# %%
df["Model"] = df.Name.str.split().str.get(1) + df.Name.str.split().str.get(2)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# ...

# %%
df[["Name", "Brand","Model" ]]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                  Model
# 0               WagonR
# 1             Creta1.6
# 2                JazzV
# ...

# %%
print(df.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
searchfor = ["Isuzu", "ISUZU","Mini","Land"]
# df[(df["Brand"] == "Isuzu") | (df["Brand"] == "ISUZU") | (df["Brand"] == "Mini") | (df["Brand"] == "Land")]
# df[df.Brand.str.contains("|".join(searchfor))]

df[df.Brand.isin(searchfor)]
# Out:
#                                          Name    Location  Year  \
# 13           Land Rover Range Rover 2.2L Pure       Delhi  2014
# 14             Land Rover Freelander 2 TD4 SE        Pune  2012
# 176                  Mini Countryman Cooper D      Jaipur  2017
# 191       Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018
# 228                 Mini Cooper Convertible S       Kochi  2017
# ...                                       ...         ...   ...
# 6919                  ISUZU D-MAX V-Cross 4X4      Jaipur  2017
# 7132                    Mini Clubman Cooper S        Pune  2017
# 7157         Land Rover Range Rover 2.2L Pure   Hyderabad  2015
# 7160                 Mini Cooper Countryman D   Hyderabad  2013
# 7198  Land Rover Discovery 4 TDV6 Auto Diesel   Hyderabad  2012
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 13                72000    Diesel    Automatic      First   12.7 kmpl
# ...

# %%
df["Brand"].replace({"ISUZU":"Isuzu", "Mini" : "Mini Cooper",  "Land":"Land Rover"}, inplace = True)

# %%
df[df.Brand.isin(searchfor)].head()
# Out:
#                          Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 2900            Isuzu MUX 4WD      Jaipur  2017              34429    Diesel
# 3624  ISUZU D-MAX V-Cross 4X4  Coimbatore  2018              20422    Diesel
# 5979  ISUZU D-MAX V-Cross 4X4      Jaipur  2017              25000    Diesel
# 6470    Isuzu MU 7 4x2 HIPACK     Kolkata  2016              45000    Diesel
# 6919  ISUZU D-MAX V-Cross 4X4      Jaipur  2017             290000    Diesel
#
#      Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 2900    Automatic      First   13.8 kmpl  2999 CC  174.57 bhp    7.0
# 3624       Manual      First   12.4 kmpl  2499 CC     134 bhp    5.0
# 5979       Manual      First   12.4 kmpl  2499 CC     134 bhp    5.0
# 6470       Manual      First  12.08 kmpl  2999 CC     161 bhp    7.0
# 6919       Manual      First   12.4 kmpl  2499 CC     134 bhp    5.0
#
#        New_Price  Price  Car_Age  Brand         Model
# ...

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# New_Price             object
# Price                float64
# Car_Age                int64
# Brand                 object
# Model                 object
# dtype: object

# %%
#Mileage, Engine, Power, NewPrice

df["Mileage"] = df["Mileage"].str.split().str.get(0).astype(float)

# %%
df["Power"] = df["Power"].str.split().str.get(0)
pd.to_numeric(df["Power"])

#Null is a string, NaN is value to python
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File lib.pyx:2391, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "null"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 df["Power"] = df["Power"].str.split().str.get(0)
# ----> 2 pd.to_numeric(df["Power"])
#       4 #Null is a string, NaN is value to python
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\tools\numeric.py:232, in to_numeric(arg, errors, downcast, dtype_backend)
#     230 coerce_numeric = errors not in ("ignore", "raise")
#     231 try:
# --> 232     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233         values,
#     234         set(),
# ...

# %%
df.replace("null",np.nan, inplace = True)
df["Power"] = pd.to_numeric(df["Power"])

# %%
df["Engine"] = df["Engine"].str.split().str.get(0)
df["Engine"] = pd.to_numeric(df["Engine"])

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
df["New_Price"] = df["New_Price"].str.split().str.get(0)
df["New_Price"] = pd.to_numeric(df["New_Price"])

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std      min        25%  \
# Year               7253.0   2013.365366      3.254421  1996.00   2011.000
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.000
# Mileage            7251.0     18.141580      4.562197     0.00     15.170
# Engine             7207.0   1616.573470    595.285137    72.00   1198.000
# Power              7078.0    112.765214     53.493553    34.20     75.000
# Seats              7200.0      5.279722      0.811660     0.00      5.000
# New_Price          1006.0     19.894324     19.813947     1.00      7.635
# Price              6019.0      9.479468     11.187917     0.44      3.500
# Car_Age            7253.0     11.634634      3.254421     6.00      9.000
#
#                         50%       75%         max
# Year                2014.00   2016.00     2019.00
# Kilometers_Driven  53416.00  73000.00  6500000.00
# Mileage               18.16     21.10       33.54
# ...

# %%
#separating categorical and numerical data

cat_columns = df.select_dtypes(include = ['object'])
num_columns = df.select_dtypes(exclude = ["object"])

# All of the following return the same thing:
# num_columns = df.select_dtypes(include = np.number)
# num_columns = df.select_dtypes(include = ["int64", "float64"])
# num_columns = df.select_dtypes(include = ["int", "float"])
num_columns
# Out:
#       Year  Kilometers_Driven  Mileage  Engine   Power  Seats  New_Price  \
# 0     2010              72000    26.60   998.0   58.16    5.0        NaN
# 1     2015              41000    19.67  1582.0  126.20    5.0        NaN
# 2     2011              46000    18.20  1199.0   88.70    5.0       8.61
# 3     2012              87000    20.77  1248.0   88.76    7.0        NaN
# 4     2013              40670    15.20  1968.0  140.80    5.0        NaN
# ...    ...                ...      ...     ...     ...    ...        ...
# 7248  2011              89411    20.54  1598.0  103.60    5.0        NaN
# 7249  2015              59000    17.21  1197.0  103.60    5.0        NaN
# 7250  2012              28000    23.08  1461.0   63.10    5.0        NaN
# 7251  2013              52262    17.20  1197.0  103.60    5.0        NaN
# 7252  2014              72443    10.00  2148.0  170.00    5.0        NaN
#
#       Price  Car_Age
# 0      1.75       15
# 1     12.50       10
# 2      4.50       14
# ...

# %%
pc = sns.color_palette("pastel6")

for col in num_columns:
    print(col)
    print("Skew :", round(df[col].skew(),2))
    
    plt.figure(figsize = (18, 6))
    
    plt.subplot(1,3,1)
    df[col].hist(grid = True, color = pc[0])
    plt.ylabel("count")
    
    plt.subplot(1,3,2)
    sns.boxplot(x = df[col], color = pc[5])
    
    plt.subplot(1,3,3)
    sns.kdeplot(df[col], fill = True, color = pc[2])
    
    plt.show()
# Out:
# Year
# Skew : -0.84
# Kilometers_Driven
# Skew : 61.58
# Mileage
# Skew : -0.44
# Engine
# Skew : 1.41
# Power
# Skew : 1.96
# Seats
# Skew : 1.9
# New_Price
# Skew : 1.84
# Price
# Skew : 3.34
# Car_Age
# Skew : 0.84

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate data
np.random.seed(42)
normal_data = np.random.normal(loc=50, scale=10, size=1000)  # Symmetric
right_skewed_data = np.random.exponential(scale=10, size=1000)  # Right-skewed
left_skewed_data = -np.random.exponential(scale=10, size=1000) + 50  # Left-skewed

# Create figure
plt.figure(figsize=(12, 5))

# Plot Normal Distribution
plt.subplot(1, 3, 1)
sns.kdeplot(normal_data, fill=True, color="blue")
plt.title("Normal (Symmetric)")

# Plot Right-Skewed Distribution
plt.subplot(1, 3, 2)
sns.kdeplot(right_skewed_data, fill=True, color="green")
plt.title("Right-Skewed (Positive)")

# Plot Left-Skewed Distribution
plt.subplot(1, 3, 3)
sns.kdeplot(left_skewed_data, fill=True, color="red")
plt.title("Left-Skewed (Negative)")

# Show plots
plt.tight_layout()
plt.show()

# %%
cat_columns.columns
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')

# %%
fig, axes = plt.subplots(3,2, figsize = (18,18))
fig.suptitle("Bar plot for all categorical variables in the dataset")
pc = sns.color_palette("pastel")
sns.countplot(ax = axes[0, 0], x = "Fuel_Type", data = df, color = pc[0], order = df["Fuel_Type"].value_counts().index)
sns.countplot(ax = axes[0, 1], x = "Transmission", data = df, color = pc[1], order = df["Transmission"].value_counts().index)
sns.countplot(ax = axes[1, 0], x = "Location", data = df, color = pc[2], order = df["Location"].value_counts().index)
axes[1, 0].set_xticklabels(axes[1, 0].get_xticklabels(), rotation=45, ha="right")
sns.countplot(ax = axes[1, 1], x = "Owner_Type", data = df, color = pc[3], order = df["Owner_Type"].value_counts().index)
sns.countplot(ax = axes[2, 0], x = "Brand", data = df, color = pc[4], order = df["Brand"].value_counts().index)
axes[2, 0].set_xticklabels(axes[2, 0].get_xticklabels(), rotation=90, ha="right")
sns.countplot(ax = axes[2, 1], x = "Model", data = df, color = pc[5], order = df["Model"].head(20).value_counts().index)
axes[2][1].tick_params(labelrotation = 90)
plt.show()

# %%
# Since Price and Kilometers driven data are highly skewed, we apply log
# transformation to to normalize them
# Function for log transformation of a column

def log_transform(data, col):
    for colname in col:
        if (data[colname] == 1.0).all():
            data[colname + '_log'] = np.log(data[colname] + 1)
        else:
            data[colname +'_log'] = np.log(data[colname])
    data.info()

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
df["P_log"] = np.log(df["Price"])
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model     P_log
# ...

# %%
df["KMD_log"] = np.log(df["Kilometers_Driven"])
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998.0   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model     P_log    KMD_log
# ...

# %%
figure, axes = plt.subplots(1,2, figsize = (12,6))
sns.kdeplot(ax = axes[0], x = df["P_log"],data = df, fill = True, color = pc[2])
sns.kdeplot(ax = axes[1],  x = df["KMD_log"],data = df, fill = True, color = pc[3])
# Out:
# <Axes: xlabel='KMD_log', ylabel='Density'>

# %%
log_transform(df, ["Kilometers_Driven", "Price"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7253 non-null   object
#  1   Location               7253 non-null   object
#  2   Year                   7253 non-null   int64
#  3   Kilometers_Driven      7253 non-null   int64
#  4   Fuel_Type              7253 non-null   object
#  5   Transmission           7253 non-null   object
#  6   Owner_Type             7253 non-null   object
#  7   Mileage                7251 non-null   float64
#  8   Engine                 7207 non-null   float64
#  9   Power                  7078 non-null   float64
#  10  Seats                  7200 non-null   float64
#  11  New_Price              1006 non-null   float64
#  12  Price                  6019 non-null   float64
#  13  Car_Age                7253 non-null   int64
# ...

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage   Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998 CC   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582 CC  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199 CC   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248 CC   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968 CC  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
figure, axes = plt.subplots(2,2, figsize = (12,6))
sns.kdeplot(ax = axes[0,0], x = df["P_log"],data = df, fill = True, color = pc[2])
sns.kdeplot(ax = axes[0,1],  x = df["KMD_log"],data = df, fill = True, color = pc[3])
sns.kdeplot(ax = axes[1,0],  x = df["Price_log"],data = df, fill = True, color = pc[4])
sns.kdeplot(ax = axes[1,1],  x = df["Kilometers_Driven_log"],data = df, fill = True, color = pc[5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P_log'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 2
# ...

# %%
#First row of plot is simply applying log transform using np.log() on an axis
#Second row is using their function which has a condtion of df[colname] == 1 which still leads to identical graphs 
#Even the values in both columns are same

# %%
df['P_log'].equals(df['Price_log'])
# Out:
# True

# %%
df.Kilometers_Driven_log.equals(df.KMD_log)
# Out:
# True

# %%
plt.bar(data = df, x = "Location", height = "Price")
plt.xticks(rotation = 45)
plt.show()

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage   Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998 CC   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582 CC  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199 CC   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248 CC   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968 CC  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...

# %%
col = sns.color_palette("muted")

# %%
figure, axes = plt.subplots(4,2, figsize = (24,40))
fig.subplots_adjust(hspace= 0.8)  # Increase vertical spacing


df.groupby("Location")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[0,0], color = col[0])
axes[0,0].set_title("Location vs Price")
axes[0,0].set_xticklabels(axes[0,0].get_xticklabels(), rotation=45, ha="right")

df.groupby("Transmission")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[0,1],color = col[1])
axes[0,1].set_title("Transmisssion vs Price")
axes[0,1].set_xticklabels(axes[0,1].get_xticklabels(), rotation=45, ha="right")

df.groupby("Fuel_Type")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[1,0],color = col[2])
axes[1,0].set_title("Fuel_Type vs Price")
axes[1,0].set_xticklabels(axes[1,0].get_xticklabels(), rotation=45, ha="right")


df.groupby("Owner_Type")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[1,1],color = col[3])
axes[1,1].set_title("Owner_Type vs Price")
axes[1,1].set_xticklabels(axes[1,1].get_xticklabels(), rotation=45, ha="right")

df.groupby("Brand")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[2,0],color = col[4])
axes[2,0].set_title("Brand vs Price")
axes[2,0].set_xticklabels(axes[2,0].get_xticklabels(), rotation=45, ha="right")

df.groupby("Model")["Price"].mean().sort_values(ascending= False).head(10).plot.bar(ax = axes[2,1],color = col[5])
axes[2,1].set_title("Model vs Price")
axes[2,1].set_xticklabels(axes[2,1].get_xticklabels(), rotation=45, ha="right")

df.groupby("Seats")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[3,0],color = col[6])
axes[3,0].set_title("Seat vs Price")
axes[3,0].set_xticklabels(axes[3,0].get_xticklabels(), rotation=45, ha="right")

df.groupby("Car_Age")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[3,1],color = col[7])
axes[3,1].set_title("Car_Age vs Price")
axes[3,1].set_xticklabels(axes[3,1].get_xticklabels(), rotation=45, ha="right")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 figure, axes = plt.subplots(4,2, figsize = (24,40))
# ----> 2 fig.subplots_adjust(hspace= 0.8)  # Increase vertical spacing
#       5 df.groupby("Location")["Price"].mean().sort_values(ascending= False).plot.bar(ax = axes[0,0], color = col[0])
#       6 axes[0,0].set_title("Location vs Price")
#
# NameError: name 'fig' is not defined

# %%
fig, axes = plt.subplots(4, 2, figsize=(24, 40))
fig.subplots_adjust(hspace=0.8)  # Increase vertical spacing

# Define the columns and titles for the plots
columns = ["Location", "Transmission", "Fuel_Type", "Owner_Type", "Brand", "Model", "Seats", "Car_Age"]
titles = ["Location vs Price", "Transmission vs Price", "Fuel_Type vs Price", "Owner_Type vs Price", 
          "Brand vs Price", "Model vs Price", "Seats vs Price", "Car_Age vs Price"]

# Loop through the columns and create the plots
for i, (col, title) in enumerate(zip(columns, titles)):
    ax = axes[i // 2, i % 2]
    if col == "Model":
        df.groupby(col)["Price"].mean().sort_values(ascending=False).head(10).plot.bar(ax=ax, color=pc[i])
    else:
        df.groupby(col)["Price"].mean().sort_values(ascending=False).plot.bar(ax=ax, color=pc[i])
    ax.set_title(title)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
    
plt.show()

# %%
# copy = df.drop(["Kilometers_Driven", "Price", 'Kilometers_Driven_log',"Price_log"], axis = 1, inplace=True)
copy = df.select_dtypes(np.number)
plt.figure(figsize=(14,10))
sns.heatmap(copy.corr(), annot=True, vmin=-1, vmax=1, cmap = "pink")
plt.show()

# %%
colormap = plt.colormaps
print(colormap)
# Out:
# ColormapRegistry; available colormaps:
# ...

# %%
#Imputing Missing Values

df.loc[df["Mileage"] == 0.0] = np.nan
df.Mileage.isnull().sum()
# Out:
# np.int64(83)

# %%
df.Mileage.fillna(value = np.mean(df["Mileage"]), inplace=True)

# %%
df.Seats.isnull().sum()
# Out:
# np.int64(121)

# %%
df[df.Engine == 0]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price, Car_Age, Brand, Model, P_log, KMD_log]
# Index: []

# %%
df.Engine.isnull().sum()
# Out:
# np.int64(116)

# %%
df.Power.isna().sum()
# Out:
# np.int64(211)

# %%
a = ["Seats", "Engine", "Power"]

for i in a:
    df[a] = df[a].fillna(value = np.nanmedian(df[a], axis = 1), inplace= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 4
#       1 a = ["Seats", "Engine", "Power"]
#       3 for i in a:
# ----> 4     df[a] = df[a].fillna(value = float(np.nanmedian(df[a], axis = 1)), inplace= True)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
a = ["Seats", "Engine", "Power"]

for i in a:
    df[i] = df[i].fillna(value = np.nanmedian(df[i]), inplace= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 4
#       1 a = ["Seats", "Engine", "Power"]
#       3 for i in a:
# ----> 4     df[i] = df[i].fillna(value = np.nanmedian(df[i]), inplace= True)
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1217, in nanmedian(a, axis, out, overwrite_input, keepdims)
#    1214 if a.size == 0:
#    1215     return np.nanmean(a, axis, out=out, keepdims=keepdims)
# -> 1217 return fnb._ureduce(a, func=_nanmedian, keepdims=keepdims,
#    1218                     axis=axis, out=out,
#    1219                     overwrite_input=overwrite_input)
#
# File c:\Users\vineet\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_function_base_impl.py:3894, in _ureduce(a, func, keepdims, **kwargs)
#    3891             index_out = (0, ) * nd
# ...

# %%
# Fill None values with a placeholder value (e.g., -1)
df_filled = df.fillna(-1)

# Now you can perform operations without encountering the error
# Example: Sorting the DataFrame by 'Price'
df_sorted = df_filled.sort_values(by='Price')
print(df_sorted.head())

# %%
np.median(df["Seats"])
# Out:
# np.float64(nan)

# %%
for i in a:
    print(float(np.nanmedian(df[i])))
# Out:
# 5.0
# 1493.0
# 94.0

# %%
np.nanmedian(df["Engine"])
# Out:
# np.float64(1493.0)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage   Engine   Power  Seats  \
# 0       CNG       Manual      First    26.60   998 CC   58.16    5.0
# 1    Diesel       Manual      First    19.67  1582 CC  126.20    5.0
# 2    Petrol       Manual      First    18.20  1199 CC   88.70    5.0
# 3    Diesel       Manual      First    20.77  1248 CC   88.76    7.0
# 4    Diesel    Automatic     Second    15.20  1968 CC  140.80    5.0
#
#    New_Price  Price  Car_Age    Brand      Model
# 0        NaN   1.75       15   Maruti     WagonR
# ...
