# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,10,100)
plt.rcParams["figure.figsize"] = 10,5
fig = plt.figure()
plt.plot(x, np.sin(x), "-", c = "red")
plt.plot(x, np.cos(x), "--", c = "green")

plt.show()

# %%
plt.plot(x, np.tan(x), "-", c = "orange")

# %%
#Changing number of points generated
x = np.linspace(0,10,2)
plt.plot(x, np.sin(x), "-", c = "red")
plt.plot(x, np.cos(x), "-", c = "blue")

# %%
x = np.linspace(0,10,10)
plt.plot(x, np.sin(x), "-", c = "red")
plt.plot(x, np.cos(x), "-", c = "blue")

# %%
#plot - only one graph as output
#subplot : more thatn 1 grpah
x = np.linspace(0,10,10)
plt.plot(x, x ** 2, "-", c = "cyan")
plt.plot(x, x ** 3, "-", c = "red")

# %%
plt.plot(x, x ** 2, "-", c = "cyan")

# %%
def quadratic_equation(a, b, c, x):
    return a * x**2 + b * x + c

# Example usage
a = 1
b = -3
c = 2
y = quadratic_equation(a, b, c, x)
print(y)

# %%
plt.plot(x,   x**2 - (3 * x) + 2, c = "cyan")
