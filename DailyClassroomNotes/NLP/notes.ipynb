# %% [markdown]
# # 🧠 Natural Language Processing (NLP) Overview
#
# ## 🔹 Tokenization
# Breaking text into smaller units called *tokens* (words, sentences, etc.)
#
# - `word_tokenize()` – Tokenizes text into words using NLTK.
# - `sent_tokenize()` – Tokenizes text into sentences.
# - `blankline_tokenize` – Splits text by blank lines.
# - `WhitespaceTokenizer().tokenize()` – Splits text based only on spaces.
# - `wordpunct_tokenize` – Splits text into words and punctuation.
#
# ### 🔸 Types of Tokens
# - **Bigram** – Sequence of 2 consecutive words
# - **Trigram** – Sequence of 3 consecutive words
# - **N-gram** – Sequence of *n* consecutive words
#
# ---
#
# ## 🔹 Stemming
# Reduces words to their root form (not necessarily valid words).
#
# - `PorterStemmer()` – Oldest stemmer, widely used, conservative.
# - `LancasterStemmer()` – More aggressive, may over-stem.
# - `SnowballStemmer` – Improved and more efficient stemming.
#
# ---
#
# ## 🔹 Lemmatization
# Reduces words to their dictionary form (*lemma*). More accurate than stemming.
#
# - `WordNetLemmatizer` – Uses WordNet lexical database for accurate root forms.
#
# ---
#
# ## 🔹 Stop Words
# Common words (e.g., *the, is, and*) that are usually removed from analysis.
#
# ---
#
# ## 🔹 Parts of Speech Tagging
# - `pos_tag()` – Tags each word with its grammatical role (noun, verb, etc.)
#
# ---
#
# ## 🔹 Named Entity Recognition (NER)
# - `ne_chunk()` – Identifies named entities like people, organizations, and locations.
#
# ---
#
# ## 🔹 WordCloud
# Visual representation of word frequency in a text.
#
# ---
#
# ## 🔹 Embedding: Converting Text to Numbers
# Transforms text into numerical data for machine learning models:
#
# - `CountVectorizer` – Converts text into word count vectors.
# - `TfidfVectorizer` – Applies TF-IDF weighting to highlight important words.
# - **Word2Vec** – Learns vector representations of words based on context.
#
# ---
